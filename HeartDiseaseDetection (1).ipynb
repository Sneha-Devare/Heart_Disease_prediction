# %%
# importing necessary libraries
import pandas as pd   # for data manipulation and data cleaning
import numpy as np     # for numerical data operations  
import seaborn as sns    # for advance visualizations
import matplotlib.pyplot as plt    # for visualizations

# %%
# loading file using read_csv method of pandas
data = pd.read_csv("C:\\Users\\HP\\Downloads\\heart.csv")

# %%
plt.figure(figure=(8,4))
sns.countplot(x="Sex",data=data,color="purple")
plt.title("univariate analysis on gender")
plt.xlabel("gender")
plt.ylabel("count")
plt.show()

# %%
# Example: df['category'] and df['value']
plt.figure(figsize=(8, 4))
sns.barplot(data=data, x='Sex', y='MaxHR',color="purple")  # ci=None removes error bars
plt.title("Gender vs MaxHR")
plt.xlabel("Gender")
plt.ylabel("MaxHR")
plt.xticks(rotation=45)  # Rotate x-axis labels if necessary
plt.show()

# %%
#distribution of age
plt.figure(figsize=(6,4))
sns.histplot(data["Age"],bins=20,kde=True,color="purple")
plt.title("univariate analysis on Age column")
plt.xlabel("Age")
plt.ylabel("frequency")
plt.savefig("sd.png")
plt.show()

# %%
plt.figure(figure=(10,8))
sns.countplot(x="ChestPainType",data=data,color="purple")
plt.title("univariate analysis on chestPainType")
plt.xlabel("ChestPaintype")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figure=(10,8))
sns.countplot(x="FastingBS",data=data,color="purple")
plt.title("univariate analysis on FastingBS")
plt.xlabel("FastingBS")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figure=(10,6))
sns.countplot(x="RestingECG",data=data,color="purple")
plt.title("univariate analysis on RestingECG")
plt.xticks(rotation=45)
plt.xlabel("RestingECG")
plt.ylabel("count")
plt.show()

# %%
#gender vs class
plt.figure(figure=(6,4))
sns.countplot(x="Sex",hue="HeartDisease",data=data,palette='dark:purple')
plt.title("Gender vs HeartDisease ")
plt.xlabel("Sex")
plt.ylabel("HeartDisease")
plt.show()

# %%
#gender vs class
plt.figure(figure=(6,4))
sns.countplot(x="Sex",hue="ChestPainType",data=data,palette="dark:purple")
plt.title("gender vs ChestPainType")
plt.xlabel("Gender")
plt.ylabel("ChestPainType")
plt.show()

# %%
plt.figure(figure=(10,8))
sns.countplot(x="HeartDisease",data=data,color="purple")
plt.title("univariate analysis on Heart Disease")
plt.xlabel("HeartDisease")
plt.ylabel("count")
plt.show()

# %%
#distribution of age
plt.figure(figsize=(6,4))
sns.histplot(data["Cholesterol"],bins=20,kde=True,color="purple")
plt.title("univariate analysis on cholesterol")
plt.xlabel("Cholesterol")
plt.ylabel("frequency")
plt.savefig("sd.png")
plt.show()

# %%
promotion_counts=data["HeartDisease"].value_counts()
promotion_counts.plot(kind="pie",autopct="%1.1f%%",colors=['purple', 'violet', 'indigo', 'purple'],labels=["not HeartDisease","HeartDisease"],figsize=(5,5),title="HeartDisease distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="HeartDisease",y="Age",data=data,color="purple")
plt.title("HeartDisease Vs Age")
plt.xlabel("HeartDisease")
plt.ylabel("Age")
plt.show()

# %%
# label encoding - converting categorical columns to numerical
from sklearn.preprocessing import LabelEncoder
df = data.copy()
categorical_columns = ['Sex', 'ChestPainType', 'FastingBS',
       'RestingECG','ExerciseAngina','ST_Slope']
le = LabelEncoder()
for col in categorical_columns:
    # fit_transform - learn from the data and apply changes
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
# ...

# %%
corr_mat = df.corr()

# %%
plt.figure(figsize=(11,8))
sns.heatmap(corr_mat,annot=True,cmap="coolwarm")
plt.title("correlation matrix")  # correlation matrix is used for checking relation between two variables
plt.show()

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
from sklearn.model_selection import train_test_split
#separate features and target column
x = df.drop(columns=["HeartDisease"])   # all features in x
y = df["HeartDisease"]    # target feature in y

# spliting data 70 % for training and 30 % for testing 
# random state for split will be same all time
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
lr=LogisticRegression(max_iter=1000)
lr.fit(x_train, y_train)
y_predlr=lr.predict(x_test)

print("Logistic Regression Classification\n: ",classification_report(y_test, y_predlr))
print("Accuracy\n: ", accuracy_score(y_test,y_predlr))
# Out:
# Logistic Regression Classification
# :                precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       112
#            1       0.92      0.84      0.88       164
#
#     accuracy                           0.86       276
#    macro avg       0.86      0.87      0.86       276
# weighted avg       0.87      0.86      0.86       276
#
# Accuracy
# :  0.8623188405797102

# %%
from sklearn import metrics
confusion_matrix=metrics.confusion_matrix(y_test,y_predlr)
cm_display =metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[0,1])
cm_display.plot()
plt.show()
